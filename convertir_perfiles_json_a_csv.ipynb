# %% [markdown]
# # 📄 Convertir perfilesSeguidores.json a CSV
#
# Lee el archivo JSON con los perfiles completos (incluyendo los 16 faltantes) y lo exporta a formato CSV para mayor compatibilidad.

# %%
import os
import json
import pandas as pd

# Rutas (ajustar en Colab si es necesario)
BASE_PATH = '/Users/geotrends/Desktop/scraping'
SCRAPERS_PATH = os.path.join(BASE_PATH, 'scrapers')

JSON_FILE = os.path.join(SCRAPERS_PATH, 'perfilesSeguidores.json')
CSV_FILE = os.path.join(SCRAPERS_PATH, 'perfilesSeguidores.csv')

print(f'📂 JSON: {JSON_FILE}')
print(f'📂 CSV destino: {CSV_FILE}')
# Out:
# 📂 JSON: /Users/geotrends/Desktop/scraping/scrapers/perfilesSeguidores.json
# 📂 CSV destino: /Users/geotrends/Desktop/scraping/scrapers/perfilesSeguidores.csv

# %%
# Cargar JSON
with open(JSON_FILE, 'r', encoding='utf-8') as f:
    perfiles = json.load(f)

df = pd.DataFrame(perfiles)
print(f'✅ Cargados {len(df):,} perfiles')
print(f'📋 Columnas: {list(df.columns)}')
df.head(3)
# Out:
# ✅ Cargados 8,855 perfiles
# 📋 Columnas: ['fullName', 'profilePicUrl', 'username', 'postsCount', 'followersCount', 'followsCount', 'private', 'verified', 'isBusinessAccount', 'biography']
#               fullName                                      profilePicUrl  \
# 0  Mauro Sanchez Muñoz  https://scontent-lga3-3.cdninstagram.com/v/t51...
# 1             Santiago  https://instagram.fcgy1-2.fna.fbcdn.net/v/t51....
# 2         Jorge Orozco  https://scontent-lga3-3.cdninstagram.com/v/t51...
#
#             username  postsCount  followersCount  followsCount  private  \
# 0  maurosanchezmunoz           5             235          3455     True
# 1       santi.toro26           0               1            36     True
# 2           jao1888n           0             146          4486    False
#
#    verified  isBusinessAccount biography
# 0     False              False
# 1     False              False
# 2     False              False

# %%
# Exportar a CSV
df.to_csv(CSV_FILE, index=False, encoding='utf-8')
print(f'💾 Guardado: {CSV_FILE}')
print(f'   {len(df):,} filas, {len(df.columns)} columnas')
# Out:
# 💾 Guardado: /Users/geotrends/Desktop/scraping/scrapers/perfilesSeguidores.csv
#    8,855 filas, 10 columnas
